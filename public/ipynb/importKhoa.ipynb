# %%
import pandas as pd

data = {
    'maKhoa': ['MT', 'SK'],
    'tenKhoa': ['Mỹ Thuật', 'Sân khấu điện ảnh']
}

df = pd.DataFrame(data)
df.to_excel('mau_khoa.xlsx', index=False, sheet_name='Khoa')
print("File đã tạo!")
# Out:
# File đã tạo!
