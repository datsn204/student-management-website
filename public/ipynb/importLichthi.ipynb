# %%
import pandas as pd
from datetime import datetime

data = [
    {
        'maLT': 'LT004',
        'maLop': 'L01',
        'maMH': 'MH01',
        'ngayThi': '2025-11-20 08:00:00', 
        'phongThi': 'A1-201',
        'ghiChu': 'Mang theo máy tính'
    }
]

df = pd.DataFrame(data)
df.to_excel('mau_lich_thi.xlsx', index=False, sheet_name='LichThi')

print("File đã tạo thành công: mau_lich_thi.xlsx")
# Out:
# File đã tạo thành công: mau_lich_thi.xlsx
