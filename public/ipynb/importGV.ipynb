# %%
import pandas as pd

data = {
    'maGV': ['GV009', 'GV010'],
    'hoTen': ['Nguyễn Văn An', 'Trần Thị Bình'],
    'hocVi': ['Thạc Sĩ', 'Tiến Sĩ'],
    'email': ['an.nguyen@university.edu', 'binh.tran@university.edu'],
    'sdt' : ['0966182476', '0989536789'],
    'maKhoa': ['CD', 'KT'],
    'maTK': ['', ''],
    'autoCreateAccount': ['Yes', 'Yes']
}

df = pd.DataFrame(data)
df.to_excel('mau_giangvien_vien.xlsx', index=False, sheet_name='GiangVien')
print("File đã tạo!")
# Out:
# File đã tạo!
