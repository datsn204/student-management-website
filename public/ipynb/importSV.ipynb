# %%
import pandas as pd

data = {
    'maSV': ['SV008'],
    'hoTen': ['Pham Van F'],
    'ngaySinh': ['2003-06-12'],
    'gioiTinh': ['Nam'],
    'email': ['sv008@edu.vn'],
    'sdt': ['0909000001'],
    'maLop': ['L01'],
    'maKhoa': ['CNTT'],
    'trangThai': ['active'],
    'maTK': [''],
    'autoCreateAccount': ['Yes']
}

df = pd.DataFrame(data)
df.to_excel('mau_sinh_vien.xlsx', index=False, sheet_name='SinhVien')
print("File đã tạo!")
# Out:
# File đã tạo!
