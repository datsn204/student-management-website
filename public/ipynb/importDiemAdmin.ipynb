# %%
import pandas as pd

data = {
    'maSV': ['SV007', 'SV007'],
    'maMH': ['MH01', 'MH02'],
    'diemQT': [7.5, 8.0],
    'diemThi': [8.0, 7.0]
}

df = pd.DataFrame(data)
df.to_excel('mau_diem_admin.xlsx', index=False, sheet_name='DiemAdmin')
print("File đã tạo!")
# Out:
# File đã tạo!
