# %%
import pandas as pd


data = [
    {
        'maSV': 'SV007',       
        'maMH': 'MH01',
        'maLop': 'L01',
        'diemQT': 7.5,
        'diemThi': 8.0,
    },
    {
        'maSV': 'SV007',
        'maMH': 'MH02',
        'maLop': 'L01', 
        'diemQT': 6.0,
        'diemThi': 7.0,
    }
]

df = pd.DataFrame(data)
df.to_excel('mau_diem_gvlop.xlsx', index=False, sheet_name='DiemLop')

print("File đã tạo: mau_diem_gvlop.xlsx")
# Out:
# File đã tạo: mau_diem_gvlop.xlsx
