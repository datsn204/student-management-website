# %%
import pandas as pd

data = [
    {
        'Mã Lớp': 'L07',
        'Mã MH': 'MH01',
        'Mã GV': 'GV001',
        'Học Kỳ': 'HK1-2025'
    },
    {
        'Mã Lớp': 'L07',
        'Mã MH': 'MH02',
        'Mã GV': 'GV001',
        'Học Kỳ': 'HK2-2025'
    }
]

df = pd.DataFrame(data)
df.to_excel('mau_phancong_giang_day.xlsx', index=False, sheet_name='PhanCong')

print(" đã tạo thành công: mau_phancong_giang_day.xlsx")
# Out:
#  đã tạo thành công: mau_phancong_giang_day.xlsx
