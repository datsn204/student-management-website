# %%
import pandas as pd

data = {
    'maLop': ['L08', 'L09'],
    'tenLop': ['73MTTM22', '73SKKS23'],
    'maKhoa': ['MT', 'SK']
}

df = pd.DataFrame(data)
df.to_excel('mau_lop.xlsx', index=False, sheet_name='Lop')
print("File đã tạo!")
# Out:
# File đã tạo!
